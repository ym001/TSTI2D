# %% [markdown]
# <a href="https://colab.research.google.com/github/ym001/TSTI2D/blob/main/tension_sinusoidale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,2*np.pi,30)
y=np.sin(x)
plt.plot(x,y,"go-")
